# %% [markdown]
# Phase 2
# State/UT wise analysis.
#
# Note :
#
# You need to be careful as this phase is whole state/ut wise analysis (not district-wise).
#
# It is up to you which columns you want to keep or delete to make proper analysis"
#
# 2.1 Analysis of Literacy Rate vs Total Crimes.
#
# 2.2 Analysis of the type of crime vs each state vs Literacy rate.
#
# 2.3 Analysis of year-on-year total crime rate.
#
# 2.4 Analysis of area vs overall crime
#
# 2.5 Analysis of Population vs overall Crime
#
# 2.6 Each state crime report. There is no fixed format to write a report, you can write a report inside the notebook itself based on what you have analyzed in the above points.

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
import plotly.express as px

# %% [markdown]
# # ANALYSIS STATE/UT-WISE

# %% [markdown]
# # 2.1)Analysis of Literacy rate vs Total crimes.

# %%
#calling the csv file
df=pd.read_csv('Indias crime project...csv')

# %%
df
# Out:
#        YEAR                       STATES/UT   Muder  Attempt to Muder  \
# 0    2001.0                   Andra Pradesh  2602.0            1555.0
# 1    2001.0               Arunachal Pradesh    83.0              53.0
# 2    2001.0                           Assam  1356.0             481.0
# 3    2001.0                           Bihar  3643.0            3419.0
# 4    2001.0                    Chhattisgarh   880.0             529.0
# ..      ...                             ...     ...               ...
# 416  2012.0  The Government of NCT of Delhi   521.0             439.0
# 417  2012.0                 Jammu & Kashmir   124.0             511.0
# 418  2012.0                     Lakshadweep     0.0               0.0
# 419  2012.0                      Puducherry    29.0              27.0
# 420     NaN                             NaN     NaN               NaN
#
#      Capable Homocide not amounting to muder   Rape  Custodial rape  \
# ...

# %%
df.head()
# Out:
#      YEAR          STATES/UT   Muder  Attempt to Muder  \
# 0  2001.0      Andra Pradesh  2602.0            1555.0
# 1  2001.0  Arunachal Pradesh    83.0              53.0
# 2  2001.0              Assam  1356.0             481.0
# 3  2001.0              Bihar  3643.0            3419.0
# 4  2001.0       Chhattisgarh   880.0             529.0
#
#    Capable Homocide not amounting to muder   Rape  Custodial rape  \
# 0                                    136.0  871.0             0.0
# 1                                      3.0   33.0             0.0
# 2                                     40.0  817.0             0.0
# 3                                    250.0  888.0             0.0
# 4                                     45.0  959.0             0.0
#
#    Kidnapping and abduction  Sexual Harassment  TOTAL - Robbery  ...  \
# 0                     765.0             3544.0            629.0  ...
# 1                      55.0               78.0             84.0  ...
# ...

# %% [markdown]
# This are the first five rows and columns of the dataset.

# %%
df.shape
# Out:
# (421, 28)

# %% [markdown]
# There are total 421 rows and 28 columns in the dataset.

# %%
df.columns
# Out:
# Index(['YEAR', 'STATES/UT', 'Muder', 'Attempt to Muder',
#        'Capable Homocide not amounting to muder', 'Rape', 'Custodial rape',
#        'Kidnapping and abduction', 'Sexual Harassment', 'TOTAL - Robbery',
#        'TOTAL - Dacoity', 'TOTAL - Burglary', 'TOTAL - Theft',
#        'Crime against children', 'Property crime', 'Total crimes committed',
#        ' Literacy Rate   (Male)', ' Literacy Rate Female',
#        ' Literacy Rate Average', 'Area(km2)', 'Population Male',
#        'Population Female', 'Population Total', 'Rural', 'Urban',
#        'predicted population increase rate  for next year',
#        'predicted literacy increase rate for next year', 'Total IPC crime'],
#       dtype='object')

# %% [markdown]
# These are the names of all the columns present in the dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421 entries, 0 to 420
# Data columns (total 28 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   YEAR                                               420 non-null    float64
#  1   STATES/UT                                          420 non-null    object
#  2   Muder                                              420 non-null    float64
#  3   Attempt to Muder                                   420 non-null    float64
#  4   Capable Homocide not amounting to muder            420 non-null    float64
#  5   Rape                                               419 non-null    float64
#  6   Custodial rape                                     420 non-null    float64
#  7   Kidnapping and abduction                           420 non-null    float64
# ...

# %% [markdown]
# This gives the inforfation of the dataset. we can see the null values, dtype of all the columns, Range index and columns.
# We can see that there are 1 null values in Rape and Sexual Harassment column.
# There rae 27 float dtype and 1 object dtype.

# %%
#checking for null values
df.isnull().sum()
# Out:
# YEAR                                                 1
# STATES/UT                                            1
# Muder                                                1
# Attempt to Muder                                     1
# Capable Homocide not amounting to muder              1
# Rape                                                 2
# Custodial rape                                       1
# Kidnapping and abduction                             1
# Sexual Harassment                                    2
# TOTAL - Robbery                                      1
# TOTAL - Dacoity                                      1
# TOTAL - Burglary                                     1
# TOTAL - Theft                                        1
# Crime against children                               1
# Property crime                                       1
# Total crimes committed                               1
#  Literacy Rate   (Male)                              1
# ...

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df['Total crimes committed'].value_counts(normalize=True)
# Out:
# 243.0      0.004762
# 26087.0    0.004762
# 1592.0     0.004762
# 31063.0    0.002381
# 31011.0    0.002381
#              ...
# 4812.0     0.002381
# 26101.0    0.002381
# 681.0      0.002381
# 25530.0    0.002381
# 1379.0     0.002381
# Name: Total crimes committed, Length: 417, dtype: float64

# %% [markdown]
# These are the total crimes committed in the following years.

# %%
df.nunique().to_frame('Muder')
# Out:
#                                                    Muder
# YEAR                                                  12
# STATES/UT                                             36
# Muder                                                325
# Attempt to Muder                                     298
# Capable Homocide not amounting to muder              160
# Rape                                                 306
# Custodial rape                                         1
# Kidnapping and abduction                             286
# Sexual Harassment                                    309
# TOTAL - Robbery                                      296
# TOTAL - Dacoity                                      219
# TOTAL - Burglary                                     380
# TOTAL - Theft                                        397
# Crime against children                               286
# Property crime                                       223
# ...

# %% [markdown]
# This are the unique values count of all the columns.

# %%
plt.figure(figsize=(8,8))
sns.lineplot(x=df['YEAR'],y=df['Total crimes committed'])
plt.xticks([x for x in range(2001,2012)])
plt.xlabel("YEARS")
plt.ylabel("Total crimes over the years ")
plt.title("Total crimes")
plt.grid()
plt.show()

# %% [markdown]
# THE GREATEST DIP CAN BE SEEN FROM YEAR 2004 TO YEAR 2005 MARKING THE GOOD DECREASE IN THE TOTAL CRIMES COMMITTED IN INDIA.
#
# One possible explanation for a decrease in crimes in India during that time period could be the implementation of strict laws and policies aimed at protecting and creating awareness among people. In 2005, the Indian government passed the Juvenile Justice (Care and Protection of Children) Act, which strengthened protections for children in various settings and provided a framework for the care and rehabilitation of women in need of protection.
#
# Another factor that could have contributed to the decrease in crimes in India is the increased attention and awareness towards different issues in the country. The Indian government and various civil society organizations have launched several campaigns and initiatives to raise awareness and to promote protection regarding different crimes against women and children.
#
# THEN IN SUBSEQUENT YEAR FROM 2005 TO 2008 THE INCREASE CAN BE SEEN IN THE TOTAL CRIME.
# Again there is decline in the year 2008 to 2009 and after that there is increase in the crimes in India.
#
# Increase in crimes could also be attributed to a variety of other factors, such as changes in societal attitudes, a breakdown in the family and community support systems, or an increase in poverty and economic insecurity.
#
# Additionally, there may have been specific events or incidents that led to a surge in crimes.

# %%
#Converting the data into float
df[' Literacy Rate   (Male)']=df[' Literacy Rate   (Male)'].astype(float)
df[' Literacy Rate Female']=df[' Literacy Rate Female'].astype(float)
df[' Literacy Rate Average']=df[' Literacy Rate Average'].astype(float)

# %%
plt.figure(figsize=(15,8),facecolor='Pink')
sns.lineplot(x=df['STATES/UT'],y=df['Total crimes committed'])
plt.xticks(rotation=90)
plt.xlabel("DIFFERENT STATES")
plt.ylabel("TOTAL CRIMES ")
plt.title("TOTAL CRIMES ACROSS DIFFERENT STATES")
plt.legend()
plt.grid()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
#  CHHATTISGARH , HARYANA ,KARNATAKA AND MAHARASHTRA ARE THE TOP 4 STATES ACCORDING TO THE TOTAL CRIMES IN THE YEARS 2001 TO 2012
#
# DADRA AND NAGAR HAVELI REMAINS THE UNION TERRITORY WITH THE LEAST NUMBER OF CRIMES RECORDED, THIS MIGHT BE DUE TO LESS POPULATION IN THIS UNION TERRITORY.

# %%
plt.figure(figsize=(15,8),facecolor='Pink')
sns.barplot(x=df['STATES/UT'],y=df[' Literacy Rate Average'],)
plt.xticks(rotation=90)
plt.xlabel("STATES/UT")
plt.ylabel("AVERAGE LIteracy rate")
plt.title("Average literacy rates among different states")
plt.show()

# %% [markdown]
# IN THE AVERAGE LITERACY RATE AMONG THE STATES OF INDIA, MADHYA PRADES RANK FIRST FOLLOWED BY NAGALAND ANG LAKSHADWEEP.
# WHERE AS BIHAR HAS THE LEAST AVERAGE LITERACY RATE AMONG ALL STATES FROM 2001 TO 2012.

# %%
plt.figure(figsize=(8,8))
sns.distplot(df[' Literacy Rate   (Male)'],hist=False,color='Red',label="MALE")
sns.distplot(df[' Literacy Rate Female'],hist=False,color='Black',label="FEMALE")
plt.title("AVERAGE LITERACY RATE DISTRIBUTION AMONG MALES AND FEMALES")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# IN THE ABOVE DIAGRAM RED IS FOR MALE AND BLACK REPRESNT FEMALE LITERACY RATE.
# IN THE AVERAGE LITERACY RATE OF INDIA FROM 2001 TO 2012,
# THE MALE LITERACY RATE IS HIGHER THAN FEMALE,THIS MAY BE DUE TO THE REASON THAT IN MOST PART OF INDIAN WOMEN ARE NOT ALLOWED FOR EDUCATION OR BECAUSE OF POVERTY.
# AND IN MOST OF THE TIME GIRLS ARE MARRIED EARLY SO THEY ARE NOT PERMITED TO GO TO SCHOOL.

# %% [markdown]
# # Relationship between the total crimes and the average literacy rate

# %%
plt.figure(figsize=(8,8),facecolor='Red')
sns.regplot(x=df[' Literacy Rate Average'],y=df['Total crimes committed'])
plt.ylabel("TOTAL CRIMES ")
plt.title("RELATIONSHIP BETWEEN TOTAL CRIMES AND LITERACY RATE ")
plt.grid()
plt.show()

# %% [markdown]
# THIS IS THE RELATIONSHIP BETWEEN THE AVERAGE LITERACY RATE AND TOTAL CRIMES COMMITTED.

# %% [markdown]
# # 2.2 Analysis of the type of crime vs each state vs Literacy rate

# %%
plt.figure(figsize=(20,8))
sns.boxplot(x=df['STATES/UT'],y=df[' Literacy Rate Average'])
sns.boxplot(x=df['STATES/UT'],y=df[' Literacy Rate   (Male)'])
sns.boxplot(x=df['STATES/UT'],y=df[' Literacy Rate Female'])
plt.xlabel("STATES/UT",fontsize=15)
plt.ylabel("Literacy Rate")
plt.xticks(rotation=90,size=15)
plt.title("LITERACY RATE ACROSS DIFFERENT STATES")
plt.show()

# %% [markdown]
# LITERACY RATE AMONG THE DIFFERENT STATES IN INDIA.
# MADHYA PRADESH HAS THE HIGHEST LITERACY RATE.
# BIHAR HAS THE LEAST LITERACY RATE, BUT IT IS SLOWLY INCREASING.

# %%
plt.figure(figsize=(8,8))
sns.distplot(df[' Literacy Rate   (Male)'],hist=False,color='Red',label="MALE")
sns.distplot(df[' Literacy Rate Female'],hist=False,color='Black',label="FEMALE")
sns.distplot(df[' Literacy Rate Average'],hist=False,color='Black',label="FEMALE")
plt.title("AVERAGE LITERACY RATE DISTRIBUTION AMONG MALES AND FEMALES")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# IN THE ABOVE LINE DIAGRAM, THE MALE HAS THE HIGHEST LITERACY RATE.
# BUT IN THE AVERAGE LITERACY RATE FEMALE LAITERACT RATE IS HIGH.
# IT HAS A SLIGHT BEND BUT THAN IT SHOWS INCLINE, THIS MAY BE DUE TO THE AWARENESS AMONG THE PEOPLE AND GOVERNMENT SCHEMES FOR GIRL CHILD EDUCATION.
# EVEN WOMEN ARE NOW KEEN ON BUILDING THEIR CAREER.

# %%
plt.figure(figsize=(20,8),facecolor='Pink')
sns.boxplot(x=df['STATES/UT'],y=df['Crime against children'])
plt.title("TOTAL CRIMES AGAINST CHILDREN BY THE BOXPLOTS")
plt.ylabel("TOTAL CRIMES AGAINST CHILDREN  ")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# THIS BOXPLOT SHOWS THE CRIME AGAINST CHILDRENS.
# UTTER PRADESH SHOWS THE HIGHEST CRIME RATE AGAINST CHILDRENS FOLLOWED BY MADHYA PRADESH.
# ALL THE UNION TERRITORY HAS THE LEAST CRIME AGAINST CHILDREN, THIS MAY BE DUE TO THE LEAST POPULATION.

# %%
plt.figure(figsize=(20,8),facecolor='Pink')
sns.boxplot(x=df['YEAR'],y=df['Crime against children'])
plt.title("TOTAL CRIMES AGAINST CHILDREN BY THE BOXPLOTS")
plt.ylabel("TOTAL CRIMES AGAINST CHILDREN  ")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# THE CRIME AGAINST CHILDREN HAS BEEN STEADILY INCREASING FROM OVER THE YEARS.
# BUT A DIP CAN BE SEEN YEAR 2008.
#
# One possible explanation for a decrease in crimes against children in India during that time period could be the implementation of stricter laws and policies aimed at protecting children from abuse.
#
# Another factor that could have contributed to the decrease in crimes against children in India is the increased attention and awareness towards child rights issues in the country. The Indian government and various civil society organizations have launched several campaigns and initiatives to raise awareness about child abuse and to promote child protection.
#
# THEN IN SUBSEQUENT YEAR FROM 2011 TO 2012 THE HIGHEST INCREASE CAN BE SEEN IN THE TOTAL CRIME
#
# Increase in crimes against children could also be attributed to a variety of other factors, such as changes in societal attitudes towards child abuse, a breakdown in the family and community support systems, or an increase in poverty and economic insecurity.

# %%
plt.figure(figsize=(15,10),facecolor='Pink')
sns.barplot(x=df['STATES/UT'],y=df['Muder'])
plt.xlabel("STATE/UT",fontsize=15)
plt.ylabel("MUDER",fontsize=15)
plt.title("TOTAL NUMBER OF MURDERS IN DIIFERENT STATES/UT OVER DIFFERENT YEARS RANGING FROM 2001 TO 2012")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# THIS SHOWS THE YEARWISE TRENDS IN THE MUDER RATE IN DIFFERENT STATES OF INDIA FROM 2001 TO 2012.
# UTTER PRADESH AND BIHAR HAS THE HIGHEST MUDER RATE AMONG ALL THE STATES OF INDIA.
#
# These states have experienced rapid urbanization in recent years, which has led to the growth of slums, unemployment, and poverty. This, in turn, has contributed to the rise in crime rates
# These states has seen frequent changes in government, which has led to a lack of stability and continuity in law enforcement and governance.
# The state's police force has been criticized for being under-resourced, corrupt, and inefficient.
#
# ANDAMAN AND NICOBAR ISLAND HAS THE LEAST MUDER RATE THIS MAY BE DUE TO LESS POPULATION AS IT IS A UNION TERRITORY.
# BUT IN THE STATES OF INDIA SIKKIM, MIZORAM GOA HAS THE LEAST MUDER RATE.

# %%
plt.figure(figsize=(15,10),facecolor='Pink')
sns.lineplot(x=df['STATES/UT'],y=df['Attempt to Muder'],label='Attempt to Muder')
sns.barplot(x=df['STATES/UT'],y=df['Muder'],label='Muder')
plt.xlabel("STATES/UT",fontsize=15)
plt.ylabel("ATTEMPT TO MUDER",fontsize=15)
plt.title("TOTAL NUMBER OF ATTEMPT TO MURDERS IN DIIFERENT STATES/UT OVER DIFFERENT YEARS RANGING FROM 2001 TO 2012")
plt.xticks(rotation=90)
#plt.yticks(df)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# AS THE MUDER RATE IS HIGH IN UTTER PRADESH THE ATTEMPT OF MUDER IS ALSO HIGH IN THE SAME STATE.

# %%
plt.figure(figsize=(15,10),facecolor='Pink')
sns.barplot(x=df['STATES/UT'],y=df['Rape'])
plt.xlabel("STATES/UT",fontsize=15)
plt.ylabel("TOTAL CASES OF RAPE",fontsize=15)
plt.title("TOTAL CASE OF RAPE RECORDED FROM 2001 TO 2012")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# The reasons behind the high number of reported rape cases in Madhya Pradesh from 2001 to 2012 may be due to a variety of factors.
#
# One of the major reasons could be inadequate law enforcement, which may make it easier for perpetrators to commit the crime without fear of being caught or punished. There may also be a lack of sensitivity among law enforcement officials towards the victims.
#
# Madhya Pradesh is a state with a significant gender gap, with women experiencing discrimination and violence in various forms. This may result in a higher incidence of rape cases.
#
# Social and cultural factors such as patriarchal norms, lack of sex education, and stigmatization of victims can contribute to a higher incidence of rape cases.
# Poverty and lack of economic opportunities may lead to a higher incidence of sexual violence as people may resort to such crimes out of desperation or frustration.

# %%
plt.figure(figsize=(15,10),facecolor='Yellow')
sns.lineplot(x=df['YEAR'],y=df['TOTAL - Robbery'],label="Robbery")
sns.lineplot(x=df['YEAR'],y=df['TOTAL - Dacoity'],label="Dacoity")
sns.lineplot(x=df['YEAR'],y=df['TOTAL - Burglary'],label="Burglary")
sns.lineplot(x=df['YEAR'],y=df['TOTAL - Theft'],label="Theft")
sns.lineplot(x=df['YEAR'],y=df['Capable Homocide not amounting to muder'],label="Capable Homocide not amounting to muder")
sns.lineplot(x=df['YEAR'],y=df['Kidnapping and abduction'],label="Kidnapping and abduction")
plt.xlabel("YEARS",fontsize=10)
plt.xticks([x for x in range(2001,2012)])
plt.ylabel("TOTAL CASES",fontsize=10)
plt.title("TOTAL CASES  ACROSS DIFFERENT STATES/UT!! ")
plt.xticks(rotation=90)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# THIS GRAPH SHOWS THE MULTIPLE CRMES IN INDIA SUCH AS-
# ROBBERY
# DACOITY
# BURGLARY
# THEFT
# CAPABLE HOMOCIDE
# KISNAPPING
# THROUGHT THE YEAR 2001 TO 2012 OF ALL THE STATES.
# AMONG ALL THE CRIMES THEFT IS HIGHEST AND DACOITY IS THE LEAST CRIME COMMITTED IN INDIA.

# %%
plt.figure(figsize=(15,8))
sns.barplot(x=df['YEAR'],y=df['Property crime'])
plt.xlabel("YEAR",fontsize=15)
plt.xticks(rotation=90)
plt.ylabel("Property crime",fontsize=15)
plt.title("TOTAL PROPERTY CRIME  ACROSS DIFERENT YEARS!!")
plt.grid(True)
plt.show()

# %% [markdown]
# THE CRIME AGAINST PROPERTY HAS INCREASED OVER THE YEARS.
# THE CRIMINALS ARE BECOMING SHARPER, AND THE MISSUSE OF TECHNOLOGY HAS BEEN PLAING A VITAL ROLL IN THIS.
# FRAUD OVER PROPERT IS HIGHEST IN 2011.
# GIVING RENT TO A SINGLE FLAT TO MULTIPLE PEOPLE OVER AND OVER AGAIN BY THE BROKER WHICH IS ILLIGAL AND CHEATING PEOPLE ,
# AND THEN RUNNING WITH THEIR DEPOSIT AMOUNT IS ONE TYPE OF FRAUD.

# %%
plt.figure(figsize=(15,8))
sns.barplot(x=df['STATES/UT'],y=df['Total IPC crime'])
plt.xlabel("STATES/UT",fontsize=15)
plt.xticks(rotation=90)
plt.ylabel("IPC crime",fontsize=15)
plt.title("TOTAL IPC CRIME  ACROSS DIFERENT STATES")
plt.grid(True)
plt.show()

# %% [markdown]
# THESE ARE THE OVERALL CRIMES RECORDED BY THE ICP OF ALL THE STATES IN INDIA FROM 2001 TO 2012.
# ACCORDING TO IPC MADHYA PRADESH HAS THE HIGHEST RATE OF OVER ALL CRIMES.
# AND UNION TERRITORIES HAS THE LEAST OVERALL CRIME RATE.

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x=df['STATES/UT'],y=df['Total IPC crime'],hue=df[' Literacy Rate Average'])
plt.xlabel("STATES")
plt.xticks(rotation=90)
plt.ylabel("TOTAL IPC CRIMES")
plt.title("TOTAL CRIMES AMONG DIFFERENT STATES HUED WITH THE LITERACY RATE GRADES")
plt.grid()
plt.show()

# %% [markdown]
# Literacy rate affect the overall crime.
# But it is suprising to see that Madhya Pradesh with the highest literacy rate has the highest crime rate too.
# This can be due to Government inefficiency, the more population rate and less job availability.
# Arunachal Pradesh has low literacy rate and low IPC crime rate too.

# %%
plt.figure(figsize=(8,8),facecolor='Pink')
sns.regplot(x=df[' Literacy Rate Average'],y=df['Rape'])
plt.xlabel(" LITERACY RATE   Average",fontsize=10)
plt.ylabel("TOTAL CASES OF RAPE",fontsize=10)
plt.title("SCATTERPLOT BETWEEN  AVERAGE LITERACY RATE AND TOTAL NUMBER OF RAPES ")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# RELATION CAN BE SEEN BETWEEN THE TOTAL CASES OF RAPE AND AVERAGE LITERACY RATE
# WITH THE INCREASE OF LITERACY, INCREASING OF AWARENESS AMOONG THE PEOPLE, PROPER EDUCATION AND COUNSELLING, THESE CASES CAN BE BROUGHT DOWN SIGNIFICANTLY.
# Literate individuals are more likely to have a better understanding of laws and their rights, including those related to sexual assault. This can help individuals recognize and report instances of sexual assault,
# and can also help them navigate the legal system more effectively.
#
# Literacy can also empower women to be more assertive and confident in their interactions with men. This can help reduce instances of sexual harassment and assault.
#
# Literacy can also play a role in changing society's attitudes towards women and gender-based violence.
# Educated individuals are more likely to hold progressive attitudes towards women's rights and gender equality,
# which can lead to a reduction in the prevalence of sexual violence.

# %%
plt.figure(figsize=(15,10),facecolor='Pink')
sns.barplot(x=df['STATES/UT'],y=df['Kidnapping and abduction'])
plt.xlabel("STATEs/UT",fontsize=15)
plt.ylabel("FEMALE ABDUCTION OUT OF TOTAL ABDUCTION",fontsize=15)
plt.title("PERCENTAGE FEMALE ABDUCTION CASES ")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# # 2.3 Analysis of year-on-year total crime rate

# %%
plt.figure(figsize=(15,8),facecolor='Pink')
sns.barplot(x=df['STATES/UT'],y=df['Total crimes committed'])
plt.xticks(rotation=90)
plt.xlabel("STATES/UT")
plt.ylabel("OVERALL CRIMES")
plt.title("OVERALL CRIMES ACROSS DIFFERENT STATES CAN BE SEEN FROM THE GRAPH FROM THE YEAR 2001 TO 2012")
plt.grid()
plt.show()

# %% [markdown]
# AS WE CAN SEEN BEFORE THE TOTAL CRIME RATE IS HIGHEST IN MAHARASHTRA AMONG ALL THE STATES FROM 2001 TO 2012.
# OVER ALL CRIME RATE OF KARNATAKA AND CHHATTISGARH IS ALSO QUEIT HIGH AND HOLDS SECOND AND THRID POSITION WHEN IT COMES IN THE RANKING
# SIKKIM HAVE THE LOWEST NUMBER OF CRIMES AMONG ALL,DUE TO LOW POPULATION DENSITY AND OTHER FACTORS LEAD TO THIS

# %%
plt.figure(figsize=(15,8),facecolor='Pink')
sns.barplot(x=df['YEAR'],y=df['Total crimes committed'])
plt.xticks(rotation=90)
plt.xlabel("YEAR")
plt.ylabel("OVERALL CRIMES")
plt.title("OVERALL CRIMES ACROSS DIFFERENT STATES CAN BE SEEN FROM THE GRAPH FROM THE YEAR 2001 TO 2012")
plt.grid()
plt.show()

# %% [markdown]
# AS WE CAN SEE THAT THE CRIME RATE HAS INCREASED OVER THE YEARS. IN COMPARESON TO 2001,
# 2012 HAS HIGHEST CRIME RATE ALMOST DOUBLE OF 2001.
#
# 2010,2011 AND 2012 SHOWS ALMOST THE SAME RATE OF CRIME PERSENTAGE.
# THERE WAS A DECLINE OF CRIME IN THE YEARS 2001, 2004 AND 2009.

# %% [markdown]
# # 2.4 Analysis of area vs overall crime

# %%
plt.figure(figsize=(15,8),facecolor='Yellow')
sns.barplot(x=df['Area(km2)'],y=df['Total crimes committed'])
plt.xticks(rotation=90)
plt.xlabel("Area(km2)")
plt.ylabel("OVERALL CRIMES!!")
plt.title("OVERALL CRIMES ACROSS DIFFERENT STATES CAN BE SEEN FROM THE GRAPH FROM THE YEAR 2001 TO 2012!")
plt.grid()
plt.show()

# %% [markdown]
# IT CAN BE SEEN CLEARLY THAT WITH THE INCREASE IN THE AREA(KM2) THE OVERALL CRIME ARE SEEN INCREASING
# SO AREA AND THE CRIME HAVE A DIRECT REALTIONSHIP BETWEEN THEM.
# INCREASE OF AREA MEANS INCREASE OF POPULATION. WITH POPULATION COMES ALL OTHER FACTORS SUCH AS POVERTY, ILLITERACY LEADIND TO DIFFERENT CRIMES.

# %% [markdown]
# # 2.5 Analysis of Population vs overall Crime

# %%
plt.figure(figsize=(8,8))
sns.distplot(x=df['Population Total'],label='TOTAL POPULATION',color='b',hist=False)
sns.distplot(x=df['Population Male'],label='MALE POPULATION',hist=False)
sns.distplot(x=df['Population Female'],label='FEMALE POPULATION',hist=False)
plt.xlabel("POPULATION")
plt.title("DENSITY COMPARISION AMONG DIFFERENT CATEGORIES")
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# FEMALE POPULATION HAS THE HIGHEST DENSITY AMONG THE TOTAL POPULATION.

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x=df['Population Total'],y=df['Total crimes committed'])
plt.xlabel("TOTAL POPULATION")
plt.ylabel("OVERALL CRIEMES")
plt.title("OVERALL CRIMES VS THE TOTAL POPULATION")
plt.grid()
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.distplot(x=df['Population Total'],label='TOTAL POPULATION',color='b',hist=False)
sns.distplot(x=df['Urban'],label='URBAN POPULATION',hist=False)
sns.distplot(x=df['Rural'],label='RURAL POPULATION',hist=False)
plt.xlabel("POPULATION")
plt.title("DENSITY COMPARISION AMONG DIFFERENT CATEGORIES")
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# URBAN POPULATION CAN BE SEEN HAVING HIGH DENSITY AND LOW SPREAD SIGNIFYING THAT THE URBAN POPULATIONS ARE CONSTRAINED IN SOME REGIONS ONLY <BR>
# TOTAL AND RURAL POPULATION HAVE WIDE SPREAD AND COMPARITIVELY LOW DENSITIES OVER THE SPECIFIC REGIONS

# %% [markdown]
# # 2.6 Each state crime report. There is no fixed format to write a report, you can write a report inside the notebook itself based on what you have analyzed in the above points.

# %% [markdown]
# According to the analysis of the different crimes committed in india,it can be considerably notice that the union territories has low crime rate,
# this may be due to the low population.As there are less density of population, people can be selfsufficient so the different factors leadind to crime are
# automatically subdued.
#
# Among all the states we have noticed that Chhattisgarh,Harayana, Karnataka and Maharashtra has the highest crime rate.Socio-economic factors make certain
# population or areas to be more  crime prone than others.For this region, poverty and poor population may be a factor for high crime incidence in.
# Madhya Pradesh has the highest literacy rate among male population. Madhya Pradesh rank second on crime against children. According
# IPC crime report Madhya Pradesh rank first in crime among all other states.The rape cases are highest in Madhya Pradesh, this makes
# Madhya Pradesh most crime rated state. This may be due to the social imbalance in the society,inequality and discrimination.
# It is strange that Madhya Pradesh having the highest literacy rate,also has the highest crime rate.
# Utter Pradesh rank first in crime against children and muder.
# The overall crime rate has increased and Maharashtra is first in the average overall crimes.
